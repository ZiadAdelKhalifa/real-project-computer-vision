# %%
from ultralytics import YOLO

import os
os.chdir(r'G:\courses\machine and Deep Learning\Computer vision\احمد ابراهيم\work\74-mask detection using YOLOv8')
model=YOLO('best.pt')

model.predict(source='Mask wearing.mp4',show=True,conf=0.25)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1684) C:\Users\Ziad\football stade.mp4: 384x640 (no detections), 208.9ms
# video 1/1 (2/1684) C:\Users\Ziad\football stade.mp4: 384x640 (no detections), 218.9ms
# video 1/1 (3/1684) C:\Users\Ziad\football stade.mp4: 384x640 1 18Yard, 197.9ms
# video 1/1 (4/1684) C:\Users\Ziad\football stade.mp4: 384x640 1 18Yard, 178.9ms
# video 1/1 (5/1684) C:\Users\Ziad\football stade.mp4: 384x640 1 18Yard, 185.9ms
# ...
